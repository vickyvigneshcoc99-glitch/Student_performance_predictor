# %% [markdown]
# # Student Performance — Exploratory Data Analysis
#
# Quick EDA notebook for the internship mini-project.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../student_dataset.csv')
df.head()

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ## Distribution of Final Score

# %%
sns.histplot(df['Final_Score'], kde=True)
plt.title('Final Score Distribution')
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
numeric_df = df.select_dtypes(include='number')
plt.figure(figsize=(8,5))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ## Hours Studied vs Final Score

# %%
sns.scatterplot(data=df, x='Hours_Studied', y='Final_Score', hue='Extracurricular_Activities')
plt.title('Hours Studied vs Final Score')
plt.show()
